# %%
from utils import mnist_reader
import plotly.express as px

# %%
x_train, y_train = mnist_reader.load_mnist('data/fashion', kind='train')
x_test, y_test = mnist_reader.load_mnist('data/fashion', kind='t10k')

# %%
print(y_train[1071])
# Out:
# 0

# %%
img = x_train[1071].reshape((28,28))
fig = px.imshow(img, color_continuous_scale='gray')
fig.update_layout(coloraxis_showscale=False)
fig.update_xaxes(showticklabels=False)
fig.update_yaxes(showticklabels=False)
fig.show()

# %%
import tadasets
from gtda.plotting import plot_point_cloud

# %%
torus = tadasets.torus(n=2000, c=2, a=1, noise=0.2)
plot_point_cloud(torus)

# %%
sphere = tadasets.dsphere(n=1000, d=3, r=3.14, noise=0.14)
plot_point_cloud(sphere)

# %%
infty_sign = tadasets.infty_sign(n=3000, noise=0.1)
plot_point_cloud(infty_sign)
